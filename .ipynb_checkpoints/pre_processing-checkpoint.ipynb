# %% [markdown]
# # Momento 1

# %% [markdown]
# ## BaseLine

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
import datetime

# %%
dataset = pd.read_excel('data/Online Retail.xlsx')

# %%
dataset.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %% [markdown]
# ### Separando data e hora

# %%
dataset['PurchaseDate'] = dataset['InvoiceDate'].apply(lambda x : x.date())
dataset['PurchaseTime'] = dataset['InvoiceDate'].apply(lambda x : x.time())

# %%
dataset.drop(['Description','Country','InvoiceDate'],axis=1,inplace=True)

# %%
dataset.head()
# Out:
#   InvoiceNo StockCode  Quantity  UnitPrice  CustomerID PurchaseDate  \
# 0    536365    85123A         6       2.55     17850.0   2010-12-01
# 1    536365     71053         6       3.39     17850.0   2010-12-01
# 2    536365    84406B         8       2.75     17850.0   2010-12-01
# 3    536365    84029G         6       3.39     17850.0   2010-12-01
# 4    536365    84029E         6       3.39     17850.0   2010-12-01
#
#   PurchaseTime
# 0     08:26:00
# 1     08:26:00
# 2     08:26:00
# 3     08:26:00
# 4     08:26:00

# %% [markdown]
# ### Criando variaveis

# %%
dataset['Amount'] = dataset[['Quantity','UnitPrice']].apply(lambda x : x[0] * x[1],axis=1)

# %%
dataset.iloc[35]
# Out:
# InvoiceNo           536370
# StockCode            22629
# Quantity                24
# UnitPrice             1.95
# CustomerID           12583
# PurchaseDate    2010-12-01
# PurchaseTime      08:45:00
# Amount                46.8
# Name: 35, dtype: object

# %%
sns.heatmap(dataset.isnull())

# %%
dataset.dropna(axis=0,subset=['CustomerID'],inplace=True)

# %%
sns.heatmap(dataset.isnull())

# %%
dataset.head()
# Out:
#   InvoiceNo StockCode  Quantity  UnitPrice  CustomerID PurchaseDate  \
# 0    536365    85123A         6       2.55     17850.0   2010-12-01
# 1    536365     71053         6       3.39     17850.0   2010-12-01
# 2    536365    84406B         8       2.75     17850.0   2010-12-01
# 3    536365    84029G         6       3.39     17850.0   2010-12-01
# 4    536365    84029E         6       3.39     17850.0   2010-12-01
#
#   PurchaseTime  Amount
# 0     08:26:00   15.30
# 1     08:26:00   20.34
# 2     08:26:00   22.00
# 3     08:26:00   20.34
# 4     08:26:00   20.34

# %% [markdown]
# ## Criando Dataset RFM(Recency, Frequency, Monetary).

# %%
rfm = pd.DataFrame()
j = datetime.date

# %% [markdown]
# Adicionando CustomerID ao dataset RFM

# %%
rfm['CustomerID'] = pd.unique(dataset['CustomerID'])

# %% [markdown]
# Adicionando Recency ao dataset RFM

# %%
customers_id_list = pd.unique(dataset['CustomerID'])
recency_list = []
for customer_id in customers_id_list:
     recency_list.append(j.today() - dataset[dataset['CustomerID'] == customer_id].sort_values(['PurchaseDate'],ascending=False)['PurchaseDate'].iloc[0])

# %%
rfm['Recency'] = recency_list

# %% [markdown]
# Adicionando Frequency ao dataset RFM

# %%
frequency_list = []
for customer_id in customers_id_list:
     frequency_list.append(len(dataset[dataset['CustomerID'] == customer_id]))

# %%
rfm['Frequency'] = frequency_list

# %% [markdown]
# Adicionando Monetary ao dataset RFM

# %%
rfm['Monetary'] = dataset.groupby('CustomerID',sort=False).sum()['Amount'].values

# %%
rfm['CustomerID'] = rfm['CustomerID'].apply(lambda x: int(x))

# %%
rfm['Recency'] = rfm['Recency'].apply(lambda x : x.days)

# %%
rfm.head()
# Out:
#    CustomerID  Recency  Frequency  Monetary
# 0       17850     2695        312   5288.63
# 1       13047     2424        196   3079.10
# 2       12583     2395        251   7187.34
# 3       13748     2488         28    948.25
# 4       15100     2723          6    635.10

# %%
rfm.describe()
# Out:
#          CustomerID      Recency    Frequency       Monetary
# count   4372.000000  4372.000000  4372.000000    4372.000000
# mean   15299.677722  2484.581199    93.053294    1898.459701
# std     1722.390705   100.772139   232.471608    8219.345141
# min    12346.000000  2393.000000     1.000000   -4287.630000
# 25%    13812.750000  2409.000000    17.000000     293.362500
# 50%    15300.500000  2443.000000    42.000000     648.075000
# 75%    16778.250000  2536.000000   102.000000    1611.725000
# max    18287.000000  2766.000000  7983.000000  279489.020000

# %%
rfm.to_csv('data/rfm.csv')

# %%
rfm = pd.read_csv('data/rfm.csv',index_col=0)

# %%
rfm = rfm.drop(['CustomerID'],axis=1)

# %%
rfm.head()
# Out:
#    Recency  Frequency  Monetary
# 0     2695        312   5288.63
# 1     2424        196   3079.10
# 2     2395        251   7187.34
# 3     2488         28    948.25
# 4     2723          6    635.10

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaled_data = scaler.fit_transform(rfm)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=3)

# %%
pca_rfm = pca.fit_transform(scaled_data)

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(pca_rfm[:,0],pca_rfm[:,1],pca_rfm[:,2])

# %%
from scipy.cluster.hierarchy import linkage, dendrogram

# %%
mergings = linkage(rfm, method='complete')

# %%
plt.figure(figsize=(20,16))
dendrogram(mergings,
           leaf_rotation=90,
           leaf_font_size=6,
)
plt.tight_layout()
plt.show()

# %%
sns.set(color_codes=True)
plt.tight_layout()
sns.clustermap(rfm,figsize=(20,20),cmap='mako')

# %% [markdown]
# ## Kmeans
#    Kmeans é um algoritmo de aprendizado não supervisionado. O K-means visa separar os dados em **k** grupos procurando diminuir a inercia de cada cluster, ou seja, o k means busca a menor soma dos quadrados de cada amostras para seu cluster mais próximo.
#
#
# $ \sum_{i=0}^{n}\min_{\mu_j \in C}(||x_j - \mu_i||^2)$

# %%
from sklearn.cluster import KMeans

# %%
error_rate = []
for n in range(1,21):
    kmeans = KMeans(n_clusters=n)
    kmeans.fit(rfm)
    error_rate.append(kmeans.inertia_)

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,21),error_rate,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
plt.title('Inertia vs. K Value')
plt.xlabel('K')
plt.ylabel('Inertia Rate')
# Out:
# Text(0,0.5,'Inertia Rate')

# %% [markdown]
# Inertia

# %%
kmeans = KMeans(n_clusters=3)

# %%
kmeans.fit(rfm)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(pca_rfm[:,0],pca_rfm[:,1],pca_rfm[:,2],c=kmeans.labels_,cmap='rainbow')

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(pca_rfm[:,2],pca_rfm[:,1],pca_rfm[:,0],c=kmeans.labels_,cmap='rainbow')

# %%
kmeans.inertia_
# Out:
# 49416897311.26081

# %%
unique, counts = np.unique(kmeans.labels_, return_counts=True)
dict(zip(unique, counts))
# Out:
# {0: 4346, 1: 3, 2: 23}

# %%
rfm.iloc[np.where(kmeans.labels_ == 2)].mean()
# Out:
# Recency       2400.347826
# Frequency     1405.521739
# Monetary     58418.754348
# dtype: float64

# %%
rfm.iloc[np.where(kmeans.labels_ == 1)].mean()
# Out:
# Recency        2396.000000
# Frequency       956.333333
# Monetary     241136.560000
# dtype: float64

# %%
rfm.iloc[np.where(kmeans.labels_ == 0)].mean()
# Out:
# Recency      2485.088127
# Frequency      85.511505
# Monetary     1434.198064
# dtype: float64

# %%
y_recency = []
for i in range(0,3):
    y_recency.append(rfm.iloc[np.where(kmeans.labels_ == i)].mean().Recency)

y_amount = []
for i in range(0,3):
    y_amount.append(rfm.iloc[np.where(kmeans.labels_ == i)].mean().Monetary)
    
y_frequency = []
for i in range(0,3):
    y_frequency.append(rfm.iloc[np.where(kmeans.labels_ == i)].mean().Frequency)


x = ['Cluster 0','Cluster 1','Cluster 2']

# %% [markdown]
# Um fator que mais chama a atenção nos grupos é a média de capital gasto

# %%
plt.subplot(1,3,1) #lines, columns, plotNumber
plt.plot(x,y_recency,'r')
plt.title('Recency')
plt.subplot(1,3,2)
plt.plot(x,y_amount)
plt.title('Monetary')
plt.subplot(1,3,3)
plt.plot(x,y_frequency)
plt.title('Frequency')
plt.tight_layout()
